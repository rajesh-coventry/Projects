# %% [markdown]
# # **Data Preparation:**

# %%
import pandas as pd
import numpy as np
import warnings

# %%
data= pd.read_csv("https://raw.githubusercontent.com/rajesh-coventry/Projects/refs/heads/master/00_DataSets/31_uber_dataset.csv")
data.shape
# Out:
# (200000, 9)

# %%
warnings.filterwarnings("ignore")

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'key', 'fare_amount', 'pickup_datetime',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'passenger_count'],
#       dtype='object')

# %%
data.head(3)
# Out:
#    Unnamed: 0                           key  fare_amount  \
# 0    24238194   2015-05-07 19:52:06.0000003          7.5
# 1    27835199   2009-07-17 20:04:56.0000002          7.7
# 2    44984355  2009-08-24 21:45:00.00000061         12.9
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1

# %%
# Rename columns: Unnamed 0 to id and 
# key to date
data.rename(columns={"Unnamed: 0": "id", "key": "date"}, inplace=True)

# %%
data.columns
# Out:
# Index(['id', 'datetime', 'fare_amount', 'pickup_datetime', 'pickup_longitude',
#        'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude',
#        'passenger_count'],
#       dtype='object')

# %% [markdown]
# | Column Name        | Description                         |
# | ------------------ | ----------------------------------- |
# | id                 | Unique id   entifier                |
# | date= pickup time  | datetime as uniqe identifier        |
# | fare\_amount       | Total fare (USD)                    |
# | pickup\_datetime   | Timestamp of pickup                 |
# | pickup\_longitude  | Pickup location (longitude)         |
# | pickup\_latitude   | Pickup location (latitude)          |
# | dropoff\_longitude | Dropoff location (longitude)        |
# | dropoff\_latitude  | Dropoff location (latitude)         |
# | passenger\_count   | Number of passengers                |

# %%
data.head(3)
# Out:
#          id                      datetime  fare_amount  \
# 0  24238194   2015-05-07 19:52:06.0000003          7.5
# 1  27835199   2009-07-17 20:04:56.0000002          7.7
# 2  44984355  2009-08-24 21:45:00.00000061         12.9
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1

# %%
data.shape
# Out:
# (200000, 9)

# %%
data["id"].nunique()
# Out:
# 200000

# %% [markdown]
# The `id` coluumn will be used as the unique identifier for this dataset.

# %%
data.dtypes
# Out:
# id                     int64
# datetime              object
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# dtype: object

# %%
data.head(3)
# Out:
#          id                      datetime  fare_amount  \
# 0  24238194   2015-05-07 19:52:06.0000003          7.5
# 1  27835199   2009-07-17 20:04:56.0000002          7.7
# 2  44984355  2009-08-24 21:45:00.00000061         12.9
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1

# %%
# Create date column from pickup_datetime
data["date_time"] = pd.to_datetime(data["pickup_datetime"]).dt.date

# %%
data.head(3)
# Out:
#          id                      datetime  fare_amount  \
# 0  24238194   2015-05-07 19:52:06.0000003          7.5
# 1  27835199   2009-07-17 20:04:56.0000002          7.7
# 2  44984355  2009-08-24 21:45:00.00000061         12.9
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
#
#    dropoff_longitude  dropoff_latitude  passenger_count   date_time
# 0         -73.999512         40.723217                1  2015-05-07
# 1         -73.994710         40.750325                1  2009-07-17
# 2         -73.962565         40.772647                1  2009-08-24

# %%
data.dtypes
# Out:
# id                     int64
# datetime              object
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# date_time             object
# dtype: object
